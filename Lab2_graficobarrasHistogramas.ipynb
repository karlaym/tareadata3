# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('ZAPLER_RV8.csv')
df.head()
# Out:
#     Documento        Estado       Fecha  Dia        Mes   Año  \
# 0  Cotizacion  No facturado  12/19/2019   19  Diciembre  2019
# 1  Cotizacion  No facturado  12/19/2019   19  Diciembre  2019
# 2  Cotizacion  No facturado  04/26/2019   26      Abril  2019
# 3  Cotizacion  No facturado  04/01/2019    1      Abril  2019
# 4  Cotizacion  No facturado  10/30/2019   30    Octubre  2019
#
#                       Area     Vendedor                       Categoria  \
# 0  Venta de repuestos Case  Jose Vicuña  Grandes Repuestos Industriales
# 1  Venta de repuestos Case  Jose Vicuña  Grandes Repuestos Industriales
# 2  Venta de repuestos Case  Simón Nuñez                 Repuestos Motor
# 3  Venta de repuestos Case  Simón Nuñez                 Repuestos Motor
# 4  Venta de repuestos Case  Jose Vicuña                 Repuestos Motor
#
#      Código  ... RatioGanancia    Costo_Unit    CostoTotal PV_Unitario  \
# 0  10332066  ...           1.4  56262.714286  56262.714286    78767.80
# 1  10332067  ...           1.4  39236.607143  39236.607143    54931.25
# 2  10330339  ...           1.4  25714.285714  25714.285714    36000.00
# 3  10330339  ...           1.4  25000.000000  25000.000000    35000.00
# 4  10331766  ...           1.4  18857.142857  18857.142857    26400.00
#
#    PV_Total      Ganancia            Motivo_VNC  Clasi_VNC  Clasi_Prod_cu  \
# 0  78767.80  22505.085714  Sin Stock en almacen  Potencial              C
# 1  54931.25  15694.642857  Sin Stock en almacen  Potencial              C
# 2  36000.00  10285.714286  Sin Stock en almacen  Potencial              C
# 3  35000.00  10000.000000  Sin Stock en almacen  Potencial              C
# 4  26400.00   7542.857143  Sin Stock en almacen  Potencial              C
#
#    Clasi_Prod_Q
# 0             Z
# 1             Z
# 2             Z
# 3             Z
# 4             Z
#
# [5 rows x 25 columns]

# %%
df.tail()
# Out:
#         Documento        Estado       Fecha  Dia        Mes   Año  \
# 18612  Cotizacion  No facturado  01/14/2019   14      Enero  2019
# 18613  Cotizacion  No facturado  09/02/2019    2  Setiembre  2019
# 18614  Cotizacion  No facturado  09/02/2019    2  Setiembre  2019
# 18615  Cotizacion  No facturado  10/19/2018   19    Octubre  2018
# 18616  Cotizacion  No facturado  10/10/2018   10    Octubre  2018
#
#                           Area     Vendedor            Categoria    Código  \
# 18612  Venta de repuestos Case  Simón Nuñez  Pequeños Repuestos   10328948
# 18613  Venta de repuestos Case  Jose Vicuña  Pequeños Repuestos   10331145
# 18614  Venta de repuestos Case  Jose Vicuña  Pequeños Repuestos   10331145
# 18615  Venta de repuestos Case  Jose Vicuña  Pequeños Repuestos   11900395
# 18616  Venta de repuestos Case  Simón Nuñez  Pequeños Repuestos   13000186
#
#        ... RatioGanancia  Costo_Unit  CostoTotal PV_Unitario  PV_Total  \
# 18612  ...           1.4         0.0         0.0         0.0       0.0
# 18613  ...           1.4         0.0         0.0         0.0       0.0
# 18614  ...           1.4         0.0         0.0         0.0       0.0
# 18615  ...           1.4         0.0         0.0         0.0       0.0
# 18616  ...           1.4         0.0         0.0         0.0       0.0
#
#        Ganancia     Motivo_VNC     Clasi_VNC  Clasi_Prod_cu  Clasi_Prod_Q
# 18612       0.0  Descontinuado  No potencial              A             Z
# 18613       0.0  Descontinuado  No potencial              A             Z
# 18614       0.0  Descontinuado  No potencial              A             Z
# 18615       0.0  Descontinuado  No potencial              A             Z
# 18616       0.0  Descontinuado  No potencial              A             Z
#
# [5 rows x 25 columns]

# %%
df.dtypes
# Out:
# Documento               object
# Estado                  object
# Fecha                   object
# Dia                      int64
# Mes                     object
# Año                      int64
# Area                    object
# Vendedor                object
# Categoria               object
# Código                   int64
# Stock                   object
# QStock                   int64
# LeadTime                 int64
# TipoImortación          object
# Qcotizada_Facturada      int64
# RatioGanancia          float64
# Costo_Unit             float64
# CostoTotal             float64
# PV_Unitario            float64
# PV_Total               float64
# Ganancia               float64
# Motivo_VNC              object
# Clasi_VNC               object
# Clasi_Prod_cu           object
# Clasi_Prod_Q            object
# dtype: object

# %%
df.columns.values
# Out:
# array(['Documento', 'Estado', 'Fecha', 'Dia', 'Mes', 'Año', 'Area',
#        'Vendedor', 'Categoria', 'Código', 'Stock', 'QStock', 'LeadTime',
#        'TipoImortación ', 'Qcotizada_Facturada', 'RatioGanancia',
#        'Costo_Unit', 'CostoTotal', 'PV_Unitario', 'PV_Total', 'Ganancia',
#        'Motivo_VNC', 'Clasi_VNC', 'Clasi_Prod_cu', 'Clasi_Prod_Q'],
#       dtype=object)

# %%
# en pandas el axis=0 representa filas (predeterminado) y el axis=1 representa columnas.
df.drop(['RatioGanancia'], axis=1, inplace=True)
df.head(2)
# se elimino la columna ratioganancia porque no es relevante
# Out:
#     Documento        Estado       Fecha  Dia        Mes   Año  \
# 0  Cotizacion  No facturado  12/19/2019   19  Diciembre  2019
# 1  Cotizacion  No facturado  12/19/2019   19  Diciembre  2019
#
#                       Area     Vendedor                       Categoria  \
# 0  Venta de repuestos Case  Jose Vicuña  Grandes Repuestos Industriales
# 1  Venta de repuestos Case  Jose Vicuña  Grandes Repuestos Industriales
#
#      Código  ... Qcotizada_Facturada    Costo_Unit    CostoTotal PV_Unitario  \
# 0  10332066  ...                   1  56262.714286  56262.714286    78767.80
# 1  10332067  ...                   1  39236.607143  39236.607143    54931.25
#
#    PV_Total      Ganancia            Motivo_VNC  Clasi_VNC  Clasi_Prod_cu  \
# 0  78767.80  22505.085714  Sin Stock en almacen  Potencial              C
# 1  54931.25  15694.642857  Sin Stock en almacen  Potencial              C
#
#    Clasi_Prod_Q
# 0             Z
# 1             Z
#
# [2 rows x 24 columns]

# %%
#Cambiemos el nombre de las columnas para que tengan sentido. Podemos usar el método rename() al ejecutar un diccionario con nombres anteriores y nuevos de la manera siguiente:

# %%
df.rename(columns={'CostotTotal':'CT', 'Clasi_Prod_cu':'Clasificacion1', 'Clasi_Prod_Q':'Clasificacion2'}, inplace=True)
df.columns
# Out:
# Index(['Documento', 'Estado', 'Fecha', 'Dia', 'Mes', 'Año', 'Area', 'Vendedor',
#        'Categoria', 'Código', 'Stock', 'QStock', 'LeadTime', 'TipoImortación ',
#        'Qcotizada_Facturada', 'Costo_Unit', 'CostoTotal', 'PV_Unitario',
#        'PV_Total', 'Ganancia', 'Motivo_VNC', 'Clasi_VNC', 'Clasificacion1',
#        'Clasificacion2'],
#       dtype='object')

# %%
df.isnull().sum()
#Podemos verificar para determinar cuántos objetos nulos hay en el conjunto de datos de la manera siguiente:
# Out:
# Documento              0
# Estado                 0
# Fecha                  0
# Dia                    0
# Mes                    0
# Año                    0
# Area                   0
# Vendedor               0
# Categoria              0
# Código                 0
# Stock                  0
# QStock                 0
# LeadTime               0
# TipoImortación         0
# Qcotizada_Facturada    0
# Costo_Unit             0
# CostoTotal             0
# PV_Unitario            0
# PV_Total               0
# Ganancia               0
# Motivo_VNC             0
# Clasi_VNC              0
# Clasificacion1         0
# Clasificacion2         0
# dtype: int64

# %%
df.describe()
# Out:
#                 Dia           Año        Código        QStock      LeadTime  \
# count  18617.000000  18617.000000  1.861700e+04  18617.000000  18617.000000
# mean      15.520707   2018.678197  1.054791e+07      2.849922     24.614761
# std        8.573948      0.477191  4.186734e+06     13.510482     11.570288
# min        1.000000   2017.000000  1.030442e+07      0.000000      7.000000
# 25%        9.000000   2018.000000  1.030573e+07      0.000000     15.000000
# 50%       15.000000   2019.000000  1.030656e+07      0.000000     30.000000
# 75%       23.000000   2019.000000  1.032950e+07      1.000000     30.000000
# max       31.000000   2019.000000  4.103319e+08    575.000000     45.000000
#
#        Qcotizada_Facturada    Costo_Unit    CostoTotal   PV_Unitario  \
# count         18617.000000  18617.000000  18617.000000  18617.000000
# mean              3.563893    155.778443    250.315220    218.089820
# std              14.793784    781.002212   1000.363083   1093.403097
# min               1.000000      0.000000      0.000000      0.000000
# 25%               1.000000     15.000000     23.657143     21.000000
# 50%               1.000000     37.035714     60.685714     51.850000
# 75%               2.000000     89.439286    167.607143    125.215000
# max             476.000000  56262.714286  56262.714286  78767.800000
#
#            PV_Total      Ganancia
# count  18617.000000  18617.000000
# mean     350.441308    100.126088
# std     1400.508316    400.145233
# min        0.000000      0.000000
# 25%       33.120000      9.462857
# 50%       84.960000     24.274286
# 75%      234.650000     67.042857
# max    78767.800000  22505.085714

# %%
#Nivel intermedio de pandas: Indexación y selección (división)
#Seleccionar columna

# %%
df.Categoria
# Out:
# 0        Grandes Repuestos Industriales
# 1        Grandes Repuestos Industriales
# 2                       Repuestos Motor
# 3                       Repuestos Motor
# 4                       Repuestos Motor
#                       ...
# 18612               Pequeños Repuestos
# 18613               Pequeños Repuestos
# 18614               Pequeños Repuestos
# 18615               Pequeños Repuestos
# 18616               Pequeños Repuestos
# Name: Categoria, Length: 18617, dtype: object

# %%
df[['Vendedor','PV_Total']]
# tenga en cuenta que 'vendedor' es una cadena y que PV_Total son números enteros.
# para mayor coherencia, convertiremos todos los nombres de las columnas en cadenas posteriormente.
#Estamos filtrando las categorias por time line
# Out:
#           Vendedor  PV_Total
# 0      Jose Vicuña  78767.80
# 1      Jose Vicuña  54931.25
# 2      Simón Nuñez  36000.00
# 3      Simón Nuñez  35000.00
# 4      Jose Vicuña  26400.00
# ...            ...       ...
# 18612  Simón Nuñez      0.00
# 18613  Jose Vicuña      0.00
# 18614  Jose Vicuña      0.00
# 18615  Jose Vicuña      0.00
# 18616  Simón Nuñez      0.00
#
# [18617 rows x 2 columns]

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
df= pd.read_csv('ZAPLER_RV8.csv')
viz = df[['LeadTime']]
viz.hist()
plt.show()

# %%
import numpy as np
import pandas as pd
df= pd.read_csv('ZAPLER_RV8.csv')
viz = df[['QStock']]
viz.hist()
plt.show()

# %%
df1 = df[["Ganancia"]]
df1[1:11].plot(kind="line")
plt.title('Tendencia')
plt.xlabel('Muestra')
plt.ylabel('Ganancia')
plt.show()
